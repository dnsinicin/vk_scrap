# %%
import pandas as pd
import tools_vk
df = pd.read_csv('result1.csv')

# %%
df.head()
# Out:
#    index      id   from_id  owner_id        date  marked_as_ads post_type  \
# 0      0  186828 -66669811 -66669811  1625394037              0      post
# 1      1  186742 -66669811 -66669811  1625306222              0      post
# 2      2  186619 -66669811 -66669811  1625245810              0      post
#
#                                                 text  \
# 0  Яна работала в таможне, мечтала стать актрисои...
# 1  На днях завершился главный международный фес...
# 2  Год назад Александр Воронин создал проект по д...
#
#                                          attachments  is_favorite  ...  \
# 0  [{'type': 'photo', 'photo': {'album_id': -7, '...        False  ...
# 1  [{'type': 'photo', 'photo': {'album_id': -7, '...        False  ...
# 2  [{'type': 'link', 'link': {'url': 'https://m.v...        False  ...
#
#   comments.count  comments.can_post  comments.groups_can_post  likes.count  \
# 0              0                  1                      True           14
# ...
